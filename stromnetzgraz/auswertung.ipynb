# %%
import pandas as pd
from csv_prepare import csv_import
from create_df import read_df

# %%
csv_import()
# Out:
# added file:  22-01-01_22-12-31_Tagstrom_Tageswerte.csv
# ()

# %%
read_df()
# Out:
#      Unnamed: 0            Ablesezeitpunkt Zaehlerstand Einheitstarif  \
# 0             0  2022-01-01 00:00:00+01:00                 466.455139
# 1             1  2022-01-02 00:00:00+01:00                 471.054932
# 2             2  2022-01-03 00:00:00+01:00                 475.654724
# 3             3  2022-01-04 00:00:00+01:00                 480.254547
# 4             4  2022-01-05 00:00:00+01:00                  484.85434
# ..          ...                        ...                        ...
# 725         360  2022-12-27 00:00:00+01:00                   2097.376
# 726         361  2022-12-28 00:00:00+01:00                    2103.27
# 727         362  2022-12-29 00:00:00+01:00                   2107.235
# 728         363  2022-12-30 00:00:00+01:00                   2113.575
# 729         364  2022-12-31 00:00:00+01:00                   2116.692
#
#      Zaehlerstand Hochtarif  Zaehlerstand Niedertarif Verbrauch Einheitstarif  \
# ...
